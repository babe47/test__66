# %%
total = 0
total += 1
total += 2
total += 3
total += 4
total += 5
total += 6
total += 7
total += 8
total += 9
total += 10
print(total)
# Out:
# 55

# %%
for word in "Hello! World!":
    print(word, end =".")
# Out:
# H.e.l.l.o.!. .W.o.r.l.d.!.

# %%
total = 0
for i in range(1,1001):
    total += i
total
# Out:
# 500500

# %%
import random

while random.randint(1,10) != 5:
    print("不等於5")

print("等於5")
# Out:
# 等於5

# %%
while True:
    if random.randint (1,5) == 5:
        break
    print("不等於5")

print("等於5")
# Out:
# 不等於5
# 不等於5
# 等於5
