# %%
chinese = int(input("請輸入國文成績:"))
english = int(input("請輸入英文成績:"))
math = int(input("請輸入數學成績:"))

total = chinese + english + math
print (total,sep="")
round(total / 3 , ndigits=3)
# Out:
# 199
# 66.333

# %%
a = 49
o = 20
f"蘋果有{a}，橘子有{o}"
# Out:
# '蘋果有49，橘子有20'

# %%
import random
# value = 0
random_value = random.randint(1,295)
random_value
# value += random_value
# print(value)
# Out:
# 92
