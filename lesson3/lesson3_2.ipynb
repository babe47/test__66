# %%
print(f"Hello, Python!")
# Out:
# Hello, Python!

# %%
s = 0
t = 8
for i in range(t):
    print(" "*(t-1)+"*"*(s+1)+"*"*(s))
    s+=1
    t-=1
# Out:
#        *
#       ***
#      *****
#     *******
#    *********
#   ***********
#  *************
# ***************

# %%
age = int(input("請輸入年齡："))
if age >= 18:
    print("可以開車" + "\n=========")
else:
    print("不可以開車" + "\n=========")
print("The End")
# Out:
# 不可以開車
# ...
# The End
